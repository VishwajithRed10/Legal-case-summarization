# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install pytorch_lightning==1.7.0 bert_score click keybert optuna torchmetrics==0.11.4 optuna==2.10.1 Levenshtein sacrebleu sacremoses summarizer
# Out:
# Requirement already satisfied: pytorch_lightning==1.7.0 in /usr/local/lib/python3.10/dist-packages (1.7.0)
# Requirement already satisfied: bert_score in /usr/local/lib/python3.10/dist-packages (0.3.13)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (8.1.7)
# Requirement already satisfied: keybert in /usr/local/lib/python3.10/dist-packages (0.8.4)
# Requirement already satisfied: optuna in /usr/local/lib/python3.10/dist-packages (2.10.1)
# Requirement already satisfied: torchmetrics==0.11.4 in /usr/local/lib/python3.10/dist-packages (0.11.4)
# Requirement already satisfied: Levenshtein in /usr/local/lib/python3.10/dist-packages (0.25.1)
# Requirement already satisfied: sacrebleu in /usr/local/lib/python3.10/dist-packages (2.4.2)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.10/dist-packages (0.1.1)
# Requirement already satisfied: summarizer in /usr/local/lib/python3.10/dist-packages (0.0.7)
# Requirement already satisfied: numpy>=1.17.2 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning==1.7.0) (1.25.2)
# Requirement already satisfied: torch>=1.9.* in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning==1.7.0) (2.2.1+cu121)
# Requirement already satisfied: tqdm>=4.57.0 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning==1.7.0) (4.66.2)
# Requirement already satisfied: PyYAML>=5.4 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning==1.7.0) (6.0.1)
# Requirement already satisfied: fsspec[http]!=2021.06.0,>=2021.05.0 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning==1.7.0) (2023.6.0)
# Requirement already satisfied: tensorboard>=2.9.1 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning==1.7.0) (2.15.2)
# Requirement already satisfied: pyDeprecate>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning==1.7.0) (0.3.2)
# Requirement already satisfied: packaging>=17.0 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning==1.7.0) (24.0)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning==1.7.0) (4.11.0)
# Requirement already satisfied: alembic in /usr/local/lib/python3.10/dist-packages (from optuna) (1.13.1)
# Requirement already satisfied: cliff in /usr/local/lib/python3.10/dist-packages (from optuna) (4.6.0)
# Requirement already satisfied: cmaes>=0.8.2 in /usr/local/lib/python3.10/dist-packages (from optuna) (0.10.0)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.10/dist-packages (from optuna) (6.8.2)
# Requirement already satisfied: scipy!=1.4.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (1.11.4)
# Requirement already satisfied: sqlalchemy>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (2.0.29)
# Requirement already satisfied: pandas>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from bert_score) (2.0.3)
# Requirement already satisfied: transformers>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from bert_score) (4.40.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from bert_score) (2.31.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from bert_score) (3.7.1)
# Requirement already satisfied: sentence-transformers>=0.3.8 in /usr/local/lib/python3.10/dist-packages (from keybert) (2.7.0)
# Requirement already satisfied: scikit-learn>=0.22.2 in /usr/local/lib/python3.10/dist-packages (from keybert) (1.2.2)
# Requirement already satisfied: rich>=10.4.0 in /usr/local/lib/python3.10/dist-packages (from keybert) (13.7.1)
# Requirement already satisfied: rapidfuzz<4.0.0,>=3.8.0 in /usr/local/lib/python3.10/dist-packages (from Levenshtein) (3.9.0)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (2.8.2)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (2023.12.25)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (0.9.0)
# Requirement already satisfied: colorama in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (0.4.6)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (4.9.4)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from sacremoses) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from summarizer) (3.8.1)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning==1.7.0) (3.9.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.1->bert_score) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.1->bert_score) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.1->bert_score) (2024.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.4.0->keybert) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.4.0->keybert) (2.16.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22.2->keybert) (3.5.0)
# Requirement already satisfied: huggingface-hub>=0.15.1 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.3.8->keybert) (0.20.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.3.8->keybert) (9.4.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.1.0->optuna) (3.0.3)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->pytorch_lightning==1.7.0) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->pytorch_lightning==1.7.0) (1.63.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->pytorch_lightning==1.7.0) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->pytorch_lightning==1.7.0) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->pytorch_lightning==1.7.0) (3.6)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->pytorch_lightning==1.7.0) (3.20.3)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->pytorch_lightning==1.7.0) (67.7.2)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->pytorch_lightning==1.7.0) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->pytorch_lightning==1.7.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->pytorch_lightning==1.7.0) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->bert_score) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->bert_score) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->bert_score) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->bert_score) (2024.2.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.*->pytorch_lightning==1.7.0) (3.14.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.*->pytorch_lightning==1.7.0) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.*->pytorch_lightning==1.7.0) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.*->pytorch_lightning==1.7.0) (3.1.3)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.*->pytorch_lightning==1.7.0) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.*->pytorch_lightning==1.7.0) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.*->pytorch_lightning==1.7.0) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.*->pytorch_lightning==1.7.0) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.*->pytorch_lightning==1.7.0) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.*->pytorch_lightning==1.7.0) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.*->pytorch_lightning==1.7.0) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.*->pytorch_lightning==1.7.0) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.*->pytorch_lightning==1.7.0) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.*->pytorch_lightning==1.7.0) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.*->pytorch_lightning==1.7.0) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.*->pytorch_lightning==1.7.0) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.9.*->pytorch_lightning==1.7.0) (12.4.127)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert_score) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert_score) (0.4.3)
# Requirement already satisfied: Mako in /usr/local/lib/python3.10/dist-packages (from alembic->optuna) (1.3.3)
# Requirement already satisfied: PrettyTable>=0.7.2 in /usr/local/lib/python3.10/dist-packages (from cliff->optuna) (3.10.0)
# Requirement already satisfied: autopage>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from cliff->optuna) (0.5.2)
# Requirement already satisfied: cmd2>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from cliff->optuna) (2.4.3)
# Requirement already satisfied: stevedore>=2.0.1 in /usr/local/lib/python3.10/dist-packages (from cliff->optuna) (5.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (3.1.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning==1.7.0) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning==1.7.0) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning==1.7.0) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning==1.7.0) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning==1.7.0) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning==1.7.0) (4.0.3)
# Requirement already satisfied: pyperclip>=1.6 in /usr/local/lib/python3.10/dist-packages (from cmd2>=1.0.0->cliff->optuna) (1.8.2)
# Requirement already satisfied: wcwidth>=0.1.7 in /usr/local/lib/python3.10/dist-packages (from cmd2>=1.0.0->cliff->optuna) (0.2.13)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->pytorch_lightning==1.7.0) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->pytorch_lightning==1.7.0) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->pytorch_lightning==1.7.0) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard>=2.9.1->pytorch_lightning==1.7.0) (1.3.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.4.0->keybert) (0.1.2)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from stevedore>=2.0.1->cliff->optuna) (6.0.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->pytorch_lightning==1.7.0) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.9.*->pytorch_lightning==1.7.0) (1.3.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.9.1->pytorch_lightning==1.7.0) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard>=2.9.1->pytorch_lightning==1.7.0) (3.2.2)

# %%
import torch
#torch.multiprocessing.set_start_method('forkserver', force=True)
from pathlib import Path
import sys
from drive.MyDrive.Group_24.preprocessor import WIKI_DOC, D_WIKI, EXP_DIR, MILDSUM
import time
import json


#from contextlib import contextmanager
import argparse

from argparse import ArgumentParser
import pytorch_lightning as pl
from pytorch_lightning.callbacks.early_stopping import EarlyStopping
from optuna.integration import PyTorchLightningPruningCallback

# from T5_2 import SumSim, train
# from Bart2 import SumSim, train
# from Bart_baseline_finetuned import BartBaseLineFineTuned, train
from drive.MyDrive.Group_24.T5_baseline_finetuned import T5BaseLineFineTuned, train


def parse_arguments():
    p = ArgumentParser()

    p.add_argument('--seed', type=int, default=42, help='randomization seed')

    # p = SumSim.add_model_specific_args(p)
    # p = BartBaseLineFineTuned.add_model_specific_args(p)
    p = T5BaseLineFineTuned.add_model_specific_args(p)
    p = pl.Trainer.add_argparse_args(p)
    args,_ = p.parse_known_args()
    return args

# class MetricsCallback(pl.Callback):
#   def __init__(self):
#     super().__init__()
#     self.metrics = []

#   def on_validation_end(self, trainer, pl_module):
#       self.metrics.append(trainer.callback_metrics)

# Create experiment directory
def get_experiment_dir(create_dir=False):
    dir_name = f'{int(time.time() * 1000000)}'
    path = EXP_DIR / f'exp_{dir_name}'
    if create_dir == True: path.mkdir(parents=True, exist_ok=True)
    return path

def log_params(filepath, kwargs):
    filepath = Path(filepath)
    kwargs_str = dict()
    for key in kwargs:
        kwargs_str[key] = str(kwargs[key])
    json.dump(kwargs_str, filepath.open('w'), indent=4)



def run_training(args, dataset):

    args.output_dir = get_experiment_dir(create_dir=True)
    # logging the args
    log_params(args.output_dir / "params.json", vars(args))

    args.dataset = dataset
    print("Dataset: ",args.dataset)
    train(args)



dataset = MILDSUM
args = parse_arguments()
print(args)
run_training(args, dataset)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# INFO:pytorch_lightning.utilities.seed:Global seed set to 42
# Namespace(seed=42, sim_model='t5-base', sum_model='t5-base', train_batch_size=6, valid_batch_size=6, learning_rate=0.0004, max_seq_length=256, adam_epsilon=1e-08, weight_decay=0.0001, warmup_steps=5, num_train_epochs=3, custom_loss=False, gradient_accumulation_steps=1, n_gpu=1, nb_sanity_val_steps=-1, train_sample_size=1, valid_sample_size=1, device='cuda', logger=True, enable_checkpointing=True, default_root_dir=None, gradient_clip_val=None, gradient_clip_algorithm=None, num_nodes=1, num_processes=None, devices=None, gpus=None, auto_select_gpus=False, tpu_cores=None, ipus=None, enable_progress_bar=True, overfit_batches=0.0, track_grad_norm=-1, check_val_every_n_epoch=1, fast_dev_run=False, accumulate_grad_batches=None, max_epochs=None, min_epochs=None, max_steps=-1, min_steps=None, max_time=None, limit_train_batches=None, limit_val_batches=None, limit_test_batches=None, limit_predict_batches=None, val_check_interval=None, log_every_n_steps=50, accelerator=None, strategy=None, sync_batchnorm=False, precision=32, enable_model_summary=True, weights_save_path=None, num_sanity_val_steps=2, resume_from_checkpoint=None, profiler=None, benchmark=None, deterministic=None, reload_dataloaders_every_n_epochs=0, auto_lr_find=False, replace_sampler_ddp=True, detect_anomaly=False, auto_scale_batch_size=False, plugins=None, amp_backend='native', amp_level=None, move_metrics_to_cpu=False, multiple_trainloader_mode='max_size_cycle')
# Dataset:  MildSum
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# MildSum
# MildSum
# /content/drive/MyDrive/Group_24/experiments/exp_1714723378762376
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/trainer/connectors/accelerator_connector.py:445: LightningDeprecationWarning: Setting `Trainer(gpus=1)` is deprecated in v1.7 and will be removed in v2.0. Please use `Trainer(accelerator='gpu', devices=1)` instead.
#   rank_zero_deprecation(
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/callbacks/model_checkpoint.py:616: UserWarning: Checkpoint directory /content/drive/MyDrive/Group_24/experiments/exp_1714723378762376 exists and is not empty.
#   rank_zero_warn(f"Checkpoint directory {dirpath} exists and is not empty.")
#  Training model
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name  | Type                       | Params
# -----------------------------------------------------
# 0 | model | T5ForConditionalGeneration | 222 M
# -----------------------------------------------------
# 222 M     Trainable params
# 0         Non-trainable params
# 222 M     Total params
# 891.614   Total estimated model params size (MB)
# init TrainDataset ...
# Initialized dataset done.....
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:558: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/trainer/trainer.py:1891: PossibleUserWarning: The number of training batches (12) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
#   rank_zero_warn(
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Sari score:  35.87990311231293
# Val_loss 0.6412009688768707
# Sari score:  34.464673854336986
# Val_loss 0.6553532614566302
# Sari score:  30.790794761240488
# Val_loss 0.6920920523875951
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 0, global step 12: 'val_loss' reached 0.66249 (best 0.66249), saving model to '/content/drive/MyDrive/Group_24/experiments/exp_1714723378762376/checkpoint-epoch=0.ckpt' as top 1
# Sari score:  33.86804802861812
# Val_loss 0.6613195197138189
# train_loss tensor(3.6675, device='cuda:0')
# val_loss tensor(0.6625, device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# Sari score:  37.02198392380213
# Val_loss 0.6297801607619786
# Sari score:  36.42841156386294
# Val_loss 0.6357158843613706
# Sari score:  32.18584388192037
# Val_loss 0.6781415611807964
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 1, global step 24: 'val_loss' reached 0.64941 (best 0.64941), saving model to '/content/drive/MyDrive/Group_24/experiments/exp_1714723378762376/checkpoint-epoch=1.ckpt' as top 1
# Sari score:  34.598869426150195
# Val_loss 0.654011305738498
# train_loss tensor(3.4454, device='cuda:0')
# val_loss tensor(0.6494, device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# Sari score:  35.55725066780677
# Val_loss 0.6444274933219323
# Sari score:  36.01968026945042
# Val_loss 0.6398031973054958
# Sari score:  32.595517765773344
# Val_loss 0.6740448223422666
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 2, global step 36: 'val_loss' was not in top 1
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=3` reached.
# Sari score:  35.263506109415985
# Val_loss 0.6473649389058401
# train_loss tensor(2.8157, device='cuda:0')
# val_loss tensor(0.6514, device='cuda:0')
# training finished
# Saving model to  /content/drive/MyDrive/Group_24/experiments/exp_1714723378762376

# %%
import click
from drive.MyDrive.Group_24.easse.utils.resources import get_orig_sents, get_refs_sents

def get_sys_sents(test_set, sys_sents_path=None):
    # Get system sentences to be evaluated
    if sys_sents_path is not None:
        return read_lines(sys_sents_path)
    else:
        # read the system output
        with click.get_text_stream("stdin", encoding="utf-8") as system_output_file:
            return system_output_file.read().splitlines()


def get_orig_and_refs_sents(test_set, orig_sents_path=None, refs_sents_paths=None):
    # Get original and reference sentences
    if test_set == "custom":
        assert orig_sents_path is not None
        assert refs_sents_paths is not None


        orig_sents = read_lines(orig_sents_path)
        # NOTE: refs_sents_paths is a list of paths
        refs_sents = [read_lines(refs_sents_paths)]
        # if type(refs_sents_paths) == str:
        #     refs_sents_paths = refs_sents_paths.split(",")
        #refs_sents = [read_lines(ref_sents_path) for ref_sents_path in refs_sents_paths]
    else:
        orig_sents = get_orig_sents(test_set)
        refs_sents = get_refs_sents(test_set)
    # Final checks
    # assert all(
    #     [len(orig_sents) == len(ref_sents) for ref_sents in refs_sents]
    # ), f'Not same number of lines for test_set={test_set}, orig_sents_path={orig_sents_path}, refs_sents_paths={refs_sents_paths}'  # noqa: E501
    return orig_sents, refs_sents

# %%
! pip install requests>=2.21.0 seaborn stanfordnlp yattag plotly>=4.0.0 tseval@git+https://github.com/facebookresearch/text-simplification-evaluation.git@main simalign
# Out:
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/text-simplification-evaluation.git /tmp/pip-install-ml14xian/tseval_9dddd27c56d04536bd995bad0800d7e0

# %%
from pathlib import Path
import sys
import os
import shutil
# sys.path.append(str(Path(__file__).resolve().parent.parent))
#sys.path.append(str(Path(__file__).resolve().parent.parent))
# -- end fix path --

from drive.MyDrive.Group_24.easse.cli import evaluate_system_output
#from Ts_T5 import T5FineTuner
from drive.MyDrive.Group_24.easse.report import get_all_scores
from contextlib import contextmanager
import json
from drive.MyDrive.Group_24.preprocessor import Preprocessor
import torch
#from transformers import T5ForConditionalGeneration, T5TokenizerFast
from drive.MyDrive.Group_24.preprocessor import get_data_filepath, EXP_DIR,  REPO_DIR, WIKI_DOC, D_WIKI
from drive.MyDrive.Group_24.preprocessor import write_lines, yield_lines, count_line, read_lines, generate_hash
from drive.MyDrive.Group_24.easse.sari import corpus_sari
from drive.MyDrive.Group_24.utils.D_SARI import D_SARI_file
import time
from drive.MyDrive.Group_24.utils.D_SARI import D_SARIsent
#from googletrans import Translator
#from Bart2 import SumSim
# from T5_2 import SumSim
from drive.MyDrive.Group_24.T5_baseline_finetuned import T5BaseLineFineTuned
# from Bart_baseline_finetuned import BartBaseLineFineTuned


@contextmanager
def log_stdout(filepath, mute_stdout=False):
    '''Context manager to write both to stdout and to a file'''

    class MultipleStreamsWriter:
        def __init__(self, streams):
            self.streams = streams

        def write(self, message):
            for stream in self.streams:
                stream.write(message)

        def flush(self):
            for stream in self.streams:
                stream.flush()

    save_stdout = sys.stdout
    log_file = open(filepath, 'w')
    if mute_stdout:
        sys.stdout = MultipleStreamsWriter([log_file])  # Write to file only
    else:
        sys.stdout = MultipleStreamsWriter([save_stdout, log_file])  # Write to both stdout and file
    try:
        yield
    finally:
        sys.stdout = save_stdout
        log_file.close()

# set random seed universal
def set_seed(seed):
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)


set_seed(42)
model_dir = None
_model_dirname = None
max_len = 256
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f'Using {device}')

# specify the model_name and checkpoint_name

# model_dirname = 'exp_WikiDocFinal_T5_kw_num4_div0.9_0.001CosSim(ReLU_W)'
# checkpoint_path = 'checkpoint-epoch=5.ckpt'

#### Single model ####
# load the model
# Model = BartBaseLineFineTuned.load_from_checkpoint('/content/experiments/checkpoint-epoch=0.ckpt').to(device)
# model = Model.model.to(device)
# tokenizer = Model.tokenizer
#### Single model ####

#### Joint model ####
Model = T5BaseLineFineTuned.load_from_checkpoint('/content/drive/MyDrive/Group_24/experiments/exp_1714723378762376/checkpoint-epoch=1.ckpt').to(device)
model = Model.model.to(device)
tokenizer = Model.tokenizer
#### Joint model ####

def generate_single(sentence, preprocessor = None):
    '''
    This function is for T5 or Bart single model to generate/predict
    '''

    # text = "simplify: " + sentence  ### -> for T5
    text = sentence
    encoding = tokenizer(text, max_length=512,
                                     padding='max_length',
                                     truncation=True,
                                     return_tensors="pt")
    input_ids = encoding["input_ids"].to(device)
    attention_masks = encoding["attention_mask"].to(device)

    # set top_k = 50 and set top_p = 0.95 and num_return_sequences = 3
    beam_outputs = model.generate(
        input_ids=input_ids,
        attention_mask=attention_masks,
        do_sample=True,
        max_length=256,
        num_beams=2,
        top_k=70,
        top_p=0.95,
        early_stopping=True,
        num_return_sequences=1,
    )
    sent = tokenizer.decode(beam_outputs[0].tolist(), skip_special_tokens=True, clean_up_tokenization_spaces=True)
    return sent


# def generate(sentence, preprocessor=None):
#     '''
#     This function is for Joint model to generate/predict
#     '''

#     # For T5
#     #sentence = 'summarize: ' + sentence

#     encoding = summarizer_tokenizer(
#         [sentence],
#         max_length = 512,
#         truncation = True,
#         padding = 'max_length',
#         return_tensors = 'pt',
#     )

#     summary_ids = summarizer.generate(
#         encoding['input_ids'].to(device),
#         num_beams = 15,
#         min_length = 30,
#         max_length = 512,
#         top_k = 80, top_p = 0.97
#     ).to(device)

#     # For T5
#     # for i, summary_id in enumerate(summary_ids):
#     #     add_tokens = torch.tensor([18356, 10]).to(device)
#     #     summary_ids[i,:] = torch.cat((summary_id, add_tokens), dim=0)[:-2]

#     summary_atten_mask = torch.ones(summary_ids.shape).to(device)
#     summary_atten_mask[summary_ids[:,:] == summarizer_tokenizer.pad_token_id] = 0

#     beam_outputs = simplifier.generate(
#         input_ids = summary_ids,
#         attention_mask = summary_atten_mask,
#         do_sample = True,
#         max_length = 256,
#         num_beams = 5, #16
#         top_k = 80,  #120
#         top_p = 0.95, #0.95
#         early_stopping = True,
#         num_return_sequences = 1,
#     )

#     sent = simplifier_tokenizer.decode(beam_outputs[0], skip_special_tokens=True, clean_up_tokenization_spaces=True)
#     return sent

    '''
    sentence = preprocessor.encode_sentence(sentence)
    text = "simplify: " + sentence
    encoding = tokenizer(text, max_length=max_len,
                                     padding='max_length',
                                     truncation=True,
                                     return_tensors="pt")
    input_ids = encoding["input_ids"].to(device)
    attention_masks = encoding["attention_mask"].to(device)

    # set top_k = 130 and set top_p = 0.97 and num_return_sequences = 1
    beam_outputs = model.generate(
        input_ids=input_ids,
        attention_mask=attention_masks,
        do_sample=False,
        max_length=max_len,
        num_beams=10,
        top_k=130,
        top_p=0.97,
        early_stopping=True,
        num_return_sequences=1
    )
    pred_sent = tokenizer.decode(beam_outputs[0], skip_special_tokens=True, clean_up_tokenization_spaces=True)
    return pred_sent
    # final_outputs = []
    # for beam_output in beam_outputs:
    #     sent = tokenizer.decode(beam_output, skip_special_tokens=True, clean_up_tokenization_spaces=True)
    #     if sent.lower() != sentence.lower() and sent not in final_outputs:
    #         final_outputs.append(sent)

    # return final_outputs
    '''


def evaluate(orig_filepath, sys_filepath, ref_filepaths):
    orig_sents = read_lines(orig_filepath)
    # NOTE: change the refs_sents if several references are used
    refs_sents = [read_lines(ref_filepaths)]
    #refs_sents = [read_lines(filepath) for filepath in ref_filepaths]

    return corpus_sari(orig_sents, read_lines(sys_filepath), refs_sents)

# def evaluate_on(dataset, features_kwargs, phase, model_dirname=None, checkpoint_path=None):

#     global model, tokenizer, device, model_dir, _model_dirname, max_len
#     device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
#     model_path = EXP_DIR / model_dirname / checkpoint_path
#     Model = T5FineTuner.load_from_checkpoint(model_path).to(device)
#     model = Model.model
#     tokenizer = Model.tokenizer
#     model_dir = EXP_DIR / model_dirname

#     # load_model(model_dirname)
#     preprocessor = Preprocessor(features_kwargs)
#     output_dir = model_dir / "outputs"
#     # output_dir = REPO_DIR / f"outputs/{_model_dirname}"
#     output_dir.mkdir(parents=True, exist_ok=True)
#     print("Output dir: ", output_dir)
#     features_hash = generate_hash(features_kwargs)
#     output_score_filepath = output_dir / f"score_{features_hash}_{dataset}_{phase}_log.txt"
#     if not output_score_filepath.exists() or count_line(output_score_filepath) == 0:
#         # log_params(output_dir / f"{features_hash}_features_kwargs.json", features_kwargs)
#         start_time = time.time()
#         complex_filepath = get_data_filepath(dataset, phase, 'complex')
#         pred_filepath = output_dir / f'{features_hash}_{complex_filepath.stem}.txt'
#         # ref_filepaths = [get_data_filepath(dataset, phase, 'simple.turk', i) for i in range(8)]
#         ref_filepath = get_data_filepath(dataset, phase, 'simple')
#         print(pred_filepath)
#         if pred_filepath.exists() and count_line(pred_filepath) == count_line(complex_filepath):
#             print("File is already processed.")
#         else:
#             simplify_file(complex_filepath, pred_filepath, preprocessor)

#         # print("Evaluate: ", pred_filepath)
#         with log_stdout(output_score_filepath):
#             # print("features_kwargs: ", features_kwargs)

#             # refs = [[line] for line in yield_lines(ref_filepath)]
#             # score = corpus_sari(read_lines(complex_filepath), read_lines(pred_filepath), refs)
#             # print(len(read_lines(complex_filepath)), len(read_lines(pred_filepath)) )
#             # print([len(s) for s in refs])

#             # scores = get_all_scores(read_lines(complex_filepath), read_lines(pred_filepath), refs)
#             score = evaluate(complex_filepath, pred_filepath, [ref_filepath])
#             # scores = evaluate_all_metrics(complex_filepath, pred_filepath, ref_filepaths)
#             if "WordRatioFeature" in features_kwargs:
#                 print("W:", features_kwargs["WordRatioFeature"]["target_ratio"], "\t", end="")
#             if "CharRatioFeature" in features_kwargs:
#                 print("C:", features_kwargs["CharRatioFeature"]["target_ratio"], "\t", end="")
#             if "LevenshteinRatioFeature" in features_kwargs:
#                 print("L:", features_kwargs["LevenshteinRatioFeature"]["target_ratio"], "\t", end="")
#             if "WordRankRatioFeature" in features_kwargs:
#                 print("WR:", features_kwargs["WordRankRatioFeature"]["target_ratio"], "\t", end="")
#             if "DependencyTreeDepthRatioFeature" in features_kwargs:
#                 print("DTD:", features_kwargs["DependencyTreeDepthRatioFeature"]["target_ratio"], "\t", end="")
#             print("{:.2f} \t ".format(score))

#             print("Execution time: --- %s seconds ---" % (time.time() - start_time))
#     else:
#         print("Already exist: ", output_score_filepath)
#         print("".join(read_lines(output_score_filepath)))

def back_translation(text):
    X = translator.translate(text, dest = 'de')
    return translator.translate(X.text, dest = 'en').text


def simplify_file(complex_filepath, output_filepath, features_kwargs=None, model_dirname=None, post_processing=True):
    '''
    Obtain the simplified sentences (predictions) from the original complex sentences.
    '''

    total_lines = count_line(complex_filepath)
    print(complex_filepath)
    print(complex_filepath.stem)

    output_file = Path(output_filepath).open("w")

    for n_line, complex_sent in enumerate(yield_lines(complex_filepath), start=1):
        ### NOTE: Change it when using Single model or Joint model
        output_sents = generate_single(complex_sent, preprocessor = None)
        #output_sents = generate(complex_sent, preprocessor=None)


        print(f"{n_line}/{total_lines}", " : ", output_sents)
        if output_sents:
            # output_file.write(output_sents[0] + "\n")
            output_file.write(output_sents + "\n")
        else:
            output_file.write("\n")
    output_file.close()

    if post_processing: post_process(output_filepath)


def post_process(filepath):
    lines = []
    for line in yield_lines(filepath):
        lines.append(line.replace("''", '"'))
    write_lines(lines, filepath)

def evaluate_on_MILDSUM(phase, features_kwargs=None,  model_dirname = None):
    dataset = MILDSUM
    #model_dir = EXP_DIR / model_dirname
    output_dir = '/content/outputs'

    #output_dir.mkdir(parents = True, exist_ok = True)

    if not os.path.exists(output_dir):
      os.makedirs(output_dir)

    #features_hash = generate_hash(features_kwargs)
    output_score_filepath = f'{output_dir}/score_{dataset}_{phase}.log.txt'
    #complex_filepath = get_data_filepath(dataset, phase, 'complex_kw_num4_div0.9') # _kw_num3_div0.9'
    complex_filepath = get_data_filepath(dataset, phase, 'complex')

    if not os.path.exists(output_score_filepath) or count_line(output_score_filepath)==0:
        start_time = time.time()
        #complex_filepath =get_data_filepath(dataset, phase, 'complex_kw_num4_div0.9')
        complex_filepath =get_data_filepath(dataset, phase, 'complex')
        complex_filepath = Path(complex_filepath)

        #complex_filepath = get_data_filepath(dataset, phase, 'complex_summary_'+str(ratio))
        pred_filepath = f'{output_dir}/{complex_filepath.stem}.txt'
        ref_filepaths = get_data_filepath(dataset, phase, 'simple')

        if os.path.exists(pred_filepath) and count_line(pred_filepath)==count_line(complex_filepath):
            print("File is already processed.")
        else:
            simplify_file(complex_filepath, pred_filepath, features_kwargs, model_dirname)

        print("Evaluate: ", pred_filepath)

        with log_stdout(output_score_filepath):

            scores  = evaluate_system_output(test_set='custom',
                                             sys_sents_path=str(pred_filepath),
                                             orig_sents_path=str(complex_filepath),
                                             refs_sents_paths=str(ref_filepaths),metrics = ['bleu', 'sari', 'fkgl'] )

            sys_sents = get_sys_sents(test_set = 'custom', sys_sents_path=str(pred_filepath))
            orig_sents, refs_sents = get_orig_and_refs_sents(test_set = 'custom',
                                                             orig_sents_path = str(complex_filepath),
                                                             refs_sents_paths = str(ref_filepaths))


            print("SARI: {:.2f}\t D-SARI: {:.2f} \t BLEU: {:.2f} \t FKGL: {:.2f} ".format(scores['sari'],
                                                                                          D_SARI_file(orig_sents,sys_sents,refs_sents[0],),
                                                                                          scores['bleu'],
                                                                                          scores['fkgl']))
            # print("{:.2f} \t {:.2f} \t {:.2f} ".format(scores['SARI'], scores['BLEU'], scores['FKGL']))

            print("Execution time: --- %s seconds ---" % (time.time() - start_time))
            return None
    else:
        print("Already exists: ", output_score_filepath)
        print("".join(read_lines(output_score_filepath)))

evaluate_on_MILDSUM(phase='test', features_kwargs=None, model_dirname=None)
# Out:
# Using cuda
# /content/drive/MyDrive/Group_24/data/MildSum/MildSum.test.complex
# MildSum.test
# 1/25  :  the matter of the petitioner-wife. In the petitioner-wife filed an application under Section 24 of the Hindu Marriage Act (for short, the Hindu Marriage Act) seeking litigation expenses of Rs.75,000/- to engage the advocate and to contest the proceedings. In the petitioner-wife filed an application under Section 24 of the Hindu Marriage Act (for short, the Hindu Marriage Act) seeking litigation expenses of Rs.75,000/- to engage the advocate and to contest the proceedings. In the petitioner-wife filed an application under Section 24 of the Hindu Marriage Act (for short, the Hindu Marriage Act) seeking litigation expenses of Rs.75,000/- to engage the advocate and to contest the proceedings. The petitioner-wife filed an application under Section 24 of the Hindu Marriage Act (for short, the petitioner-wife filed an application under Section 24 of the Hindu Marriage Act (for short, the Hindu Marriage Act) seeking litigation expenses of Rs.75,000/- to engage the advocate. The petitioner-wife filed an application under Section 24 of the Hindu Marriage Act) seeking litigation expenses of Rs.75,000/- to engage the advocate and to contest the proceedings. The petitioner-wife filed an application under Section
# 2/25  :  Aaditya Kiran was born in USA on 21st January 2016 and is holding a USA passport. However, the parents were not in a position to secure an appointment of a doctor in USA for surgery. Thus, the parents were not in a position to secure an appointment of a doctor in USA for surgery. The parents were not in a position to secure an appointment of a doctor in USA for surgery. The court held that the child will undergo surgery at Max Hospital, Saket, New Delhi. The court held that the parents were in a citizen of USA on 21st January 2016 and it was held that the child is in a position to secure an appointment of a doctor in USA for surgery. The court held that the child was in a position to secure an appointment of a doctor in USA for surgery. The court held that the child was in a position to secure an appointment of a doctor in USA for international travel with a legal guardian. The court held that a legal guardian. The court held that the child was in USA for international travel with a legal guardian. The court held that the child was in USA for international travel with
# 3/25  :  a child due to poverty and lack of legal knowledge and guidance, the petition filed by appellant Nos.1 and 2 filed an appeal against the judgment filed by appellant Nos.1 and 2. The petition filed by appellant Nos.1 and 2 filed an appeal against the judgment filed by appellant Nos.1 and 2. The petition filed by appellant Nos.1 and 2 filed an appeal against the judgment filed by the trial Court under Sections 7 to 10 and 25 of the Guardians and Wards Act, 1890, it was complied by appellant Nos.1 and 2 was denied by appellant Nos.1 and 2. The petition before the trial Court under Sections 7 to 10 and 25 of the Guardians and Wards and Wards of the Court under Sections 7 to 10 and 25 of the Guardians and Wards of the Guardians and Wards of the Guardians and Wards of the Guardians and Wards of the Guardians and Wards of the Guardians and Wards of the Guardians and Wards of the Guardians and Wards of the Guardians and Wards of the Guardians and Wards of the Guardians and Wards of the Guardian
# 4/25  :  The Indian High Court has held that the petition can be taken at the motion stage without issuing any formal notice to the respondents. The Indian High Court has held that the petition can be taken at the motion stage without issuing any formal notice to the respondents. The Indian High Court has held that the petition can be taken at the motion stage without issuing any formal notice to the petitioner. The Indian High Court has held that the petition can be taken at the motion stage without issuing any formal notice to the petitioner. The Indian High Court has held that the petition is taken at the motion stage without issuing a formal notice to the petitioner's request to the petitioner's request to the petitioner's request to the petitioner's request to the petitioner's request to the petitioner's request to the petitioner's request to the petitioner's request to the petitioner's request to the petitioner's request to the petitioner's request to the petitioner's request to the petitioner's request to the petitioner's request to the petitioner's request to the petitioner's request to the petitioner's request to the petitioner's request to
# 5/25  :  despite taking possession, award was not passed and no amount of compensation was paid to the land owners. The High Court held that despite taking possession, award was not passed and no amount of compensation was paid to the land owners. The High Court held that despite taking possession, award was not passed and no amount of compensation was paid to the land owners. The High Court held that despite taking possession, award was not passed. The High Court held that the award was not passed. The High Court held that the award was made to the land owners’ compensation was not passed and no amount of compensation was not passed. The High Court held that the compensation was not passed. The Land Acquisition Act. The Land Acquisition Act. The Land Acquisition Act. The Land Acquisition Act. The Land Acquisition Act. The Land Acquisition Act. The Land Acquisition Act. The Land Acquisition Act. The High Court held that the award was not passed. The Land Acquisition Act. The Land Acquisition Act. The Land Acquisition Act. The Land Acquisition Act. The Land Acquisition Act. The Land Acquisition Act. The Land Acquisition Act. The Land Acquisition Act. The Land Acquisition Act. The Land Acquisition Act. The Land Acquisition Act. The Land Acquisition Act. The Land Acquisition Act. The
# 6/25  :  the Chief Minister of the United State of Andhra Pradesh and the Chief Minister of the United State of Andhra Pradesh. It is submitted that the Supreme Court opted to transfer the investigation to the CBI in a time bound manner. It is submitted that the State Government opted to transfer the investigation to the CBI. It is submitted that the Supreme Court was pleased to transfer the investigation to the CBI. It is submitted that the incident pertains to the mysterious death of Shri Y.S. Vivekananda Reddy. The Supreme Court opted to transfer the investigation to the Chief Minister of the State of Andhra Pradesh. The Supreme Court also opted to transfer the investigation to the CBI in a time bound manner. The State Government opted to transfer the investigation to a time bound manner. It is submitted that the incident pertains to the mysterious death of Shri Y.S. Vivekananda Reddy. The State Government constituted a mysterious death of Shri Y.S. Vivekananda Reddy. The State Government constituted a Special Investigation Team (SIT. The State Government. The State Government. The State Government. The State
# 7/25  :  the Supreme Court ruled that the Supreme Court ruled that the Court had not heard the petition filed by a petition filed by a petition filed by a petition filed by a petition filed by a petition filed by a petition filed by a petition filed by a petition filed by a petition filed by a petition filed by a petition filed by the petition filed by a petition filed by a petition filed by a petition filed by a petition filed by a petition filed by a petition filed by a petition filed by a petition filed by the petition filed by the petition filed by a petition filed by a petition filed by a petition filed by a petition filed by a petition filed by a petition filed by a petition filed by a petition filed by a petition filed by a petition filed by a petition filed by a petition filed by a petition filed by a petition filed by a petition filed by a petition filed by a petition filed by a petition filed by a petition filed by a petition filed by a petition filed by a petition filed by a petition filed by a petition filed by a petition filed by the
# 8/25  :  The Supreme Court has ruled that no person can act as an aggregator without a licence from such authority and subject to such conditions as may be prescribed by the State Government. The Supreme Court has also ruled that no person can act as an aggregator without a licence from such authority and subject to such conditions as may be prescribed by the State Government. The Supreme Court has also ruled that the State Government is not responsible for aggregators. The Supreme Court held that no person can act as an aggregator without a licence from such authority and subject to such conditions as may be prescribed by the State Government. The Supreme Court held that no person can act as an aggregator without aggregator without aggregator without aggregator without aggregator without aggregator without aggregator without aggregator without aggregator without aggregator without aggregator without aggregator without aggregator without aggregator without aggregator without aggregator without aggregator without aggregator without aggregator without aggregator without aggregator without aggregator without aggregator without aggregator without aggregator without aggregator without aggregator without aggregator without aggregat
# 9/25  :  the Supreme Court of India had held that the Supreme Court had held that a person who contests from more than one seat at a time should not be permitted to contest from more than one seat at a time. The Supreme Court held that the Supreme Court had held that a person who contests from more than one seat at a time should not be allowed to contest from more than one seat at a time. The Supreme Court has held that the constitutional validity of Section 33(7) of the Representation of the People Act 1951 should not be allowed to contesting from more than one seat at a time should not be permitted to contest from more than one seat at a time. The Supreme Court held that a seat at a seat at a seat at a seat at a seat at a seat at a seat at a seat at a seat at a seat at a seat at a seat at a seat at a seat at a seat at a seat at a seat at a seat at a seat at a seat at a seat at a seat at a seat at a seat at a seat at a seat at a seat
# 10/25  :  Earlier it was mentioned that the Supreme Court had issued an order for the maintenance of Rs.10,000/- per month to the respondent no.2 from the date of the order. The Supreme Court held that the maintenance of Rs.10,000/- per month to the respondent no.2 from the date of the order. The Supreme Court held that the maintenance of Rs.40,000/- per month was not granted to the petitioner. The Supreme Court held that the maintenance of Rs.10,000/- per month to the respondent on account of harassment and torture against the petitioner had issued an order for the maintenance of Rs.10,000/- per month as interim maintenance. The Supreme Court observed that the petitioner. The petitioner, the petitioner. The petitioner had issued an order. The petitioner had issued an order under Section 125 Cr.P.C.C.C.C.C.C.C.C.C.C.C.C.C.C.C.C.C.C.C.C.C.C.C.C.C.C.C.C.C.C.C.C.C.C.C.C.C.C.C
# 11/25  :  The Supreme Court has held that ONGC was a contractor’s workmen and not a contractor’s workmen. The Supreme Court has held that ONGC was a contractor’s workmen and not a contractor’s workmen. The Supreme Court has held that ONGC was a contractor’s workmen and not a contractor. The Supreme Court has held that ONGC was a contractor’s workmen. The Supreme Court has held that ONGC was a contractor. The Supreme Court has held that ONGC a contractor’s workmen. The Supreme Court has held that ONGC. The Supreme Court held that ONGC. The Supreme Court has held that ONGC. The Supreme Court held that ONGC. The Supreme Court has held that it was a contractor’s workmen engaged by contractors’ workmen engaged by contractors. In fact, the ONGC. The Supreme Court has held that the ONGC. The Supreme Court has held that the MoU was a contract labourer. In fact, the contract labourer. In fact, the contract labourer. In fact, the contract labourer. In fact, the contract labour
# 12/25  :  of the Indian Constitution, the Supreme Court has held that a candidate must possess the requisite qualification of B.Com and Diploma in Journalism. The Supreme Court has held that a candidate must possess the requisite qualification of B.Com and Diploma in Journalism. The Supreme Court has held that a candidate must possess the requisite qualification of B.Com and Diploma in Journalism. The Supreme Court has held that a candidate must possess the requisite qualification of B.Com and Diploma in Journalism. The Supreme Court has held that a candidate must possess the prerequisite qualification of B.Com and Diploma in Journalism. The Supreme Court has held that a candidate must possess a candidate must possess the prerequisite qualification of B.Com and Diploma in Journalism. The Supreme Court has held that the candidate must possess the prerequisite qualification of B.Com and Diploma in Journalism. The petitioner is not a candidate must possess the prerequisite qualification for being a candidate must possess the prerequisite qualification of B.Com and Diploma in Journalism. The Supreme Court has held that a candidate must possess the prerequisite qualification for being a candidate must possess the prerequisite qualification for being a candidate must possess the prerequisite qualification for being a candidate must possess the prerequisite qualification for being a
# 13/25  :  The Delhi High Court has held that the award under Section 31 of the Arbitration and Conciliation Act, 1996 (hereinafter referred to as the "1996 Act") would include the interest pendente lite or not. The Delhi High Court has held that the award under Section 31 of the Arbitration and Conciliation Act, 1996 (hereinafter referred to as the "1996 Act") would include the interest pendente lite or not. The Delhi High Court held that the award under Section 36.2 of the Concession Agreement, in the event of termination, in the event of termination, the award under Article 36.2 of the Arbitral Award would include the interest pendente lite or not. The Delhi High Court has held that the award under Section 36.2 of the Concession Agreement, in the event of termination, in the event of termination, in the event of termination, in the event of termination, in the event of termination, in the event of termination, in the event of termination, in the event of termination, in the event of termination, in the event of termination, in the event of termination, in the event of termination, in the event of termination, in the event of termination, in
# 14/25  :  the Supreme Court had ruled that a child should have been born on 22/08/1993. The Supreme Court has ruled that a child should have been born on 22/08/1993. The Supreme Court has ruled that a child should be born on 22/08/1993. The Supreme Court has ruled that a child should have been born on 22/08/1993. The Supreme Court has ruled that a child should be born on 22/08/1993. The petitioner should have been born on 22/02/1991. The petitioner should have been born on 22/08/1993. The petitioner should have been born on 22/08/1993. The petitioner’s birth date should have been registered in the school record should be recorded in the school record should have been recorded in the school record should be recorded in the school record should have been recorded in the school record should be recorded in the school record should have been recorded in the school record should have been recorded in the school record should have been recorded in the school record should have been recorded in the school record should have been recorded in the school record should have been recorded in the school record should have been recorded in the school record should
# 15/25  :  The Delhi High Court has said that the marriage of the petitioner and the respondent was also dissolved without any force, pressure or coercion. The Delhi High Court has said that the marriage of the petitioner and the respondent was dissolved without any force, pressure or coercion. The Delhi High Court has also said that the marriage of the petitioner and the respondent was dissolved without any force, pressure or coercion. The Delhi High Court has said that the petitioner and the respondent were dissolved without any force, without any coercion. The petitioner and respondent and the petitioner and the petitioner and the petitioner-husband and the petitioner-husband and the petitioner-husband and the petitioner-husband and the petitioner-husband and the petitioner-husband and the petitioner-husband and the petitioner-husband and the petitioner-husband and the petitioner-husband and the petitioner-husband and the petitioner-husband and the petitioner-husband and the petitioner-husband and the petitioner-husband and the petitioner-husband and the petitioner-husband and the
# 16/25  :  a competitive examination was held for filling up the post of English and Hindi Stenographers in the year 1987. As per Rule 14(3) of the Subordinate Civil Courts Ministerial Establishment Rules, 1947, there were no vacancies in the judgeship for filling up the post of English Stenographers. The High Court observed that the appointment of the appellants was terminated once the regular employees resumed their duties. The High Court observed that the appointment of the appellants was terminated once the regular employees resumed their duties. The appellants were terminated once the post of English Stenographers in the year 1987. The Subordinate Civil Courts Ministerial Establishment Rules, 1947, there were no vacancies of English Stenographers. The appellants. The appellants were terminated once the regular employees. At this stage, the appointment of the appellants. The appellants. The appellants. The appellants. The appellants. The appellants. The appellants. The appellants. The appellants. The appellants. The appellants. The appellants. The appellants. The appel
# 17/25  :  The Indian Court has observed that the issuance of the Passport is not a bar for issuance of the Passport. The Indian Court has observed that the issuance of the Passport is not a bar for issuance of the Passport. The Court has observed that the issuance of Passport is not a bar for issuance of Passport. The Indian Court has observed that the issuance of Passport is not a bar for issuance of Passport. The Indian Court has observed that the issuance of Passport is not a bar for issuance of Passport is not a bar for issuance of Passport. The Indian Embassy. The Indian Embassy is not a bar for issuance of Passport is not a bar for issuance of Passport in the Indian Embassy. The Indian Embassy. The Indian Embassy. The Indian Embassy. The Indian Embassy. The Indian Embassy. The Indian Embassy. The Indian Embassy. The Indian Embassy. The Indian Embassy. The Indian Embassy. The Indian Embassy. The Indian Embassy in India is not a bar for issuance of Passport. The Indian Embassy. The Indian Embassy. The Indian Embassy. The Indian Embassy. The Indian Embassy. The Indian Embassy. The
# 18/25  :  The Supreme Court has held that the petitioners have asked for approval of the appointment of a teacher against sanctioned vacancy in view of the resignation of the incumbent on 31.07.1997. The petitioners have asked for approval of her appointment against sanctioned vacancy in view of the resignation of the incumbent on 31.07.1997. The petitioners have sought to set aside the common order dated 18.12.2020 passed in W.P.Nos.1573,1574 and 1577 of 2021. The petitioners have asked for approval of the petitioners have requested that the application for approval of the appointment of a teacher against sanctioned vacancy in view of the resignation of the incumbent on 31.07.1995 which prohibits the appointment of higher qualified persons to be appointed against sanctioned appointment of the incumbent on 31.07.1995 which prohibited the appointment of the incumbent on 31.07.1995 passed in W.P.Nos.1573,1574 and 1577 of 2021. The petitioners have asked for approval of the Supreme Court of Tamil Nadu Private School Regulation Act of Tamil Nadu Private School Regulation Act of Tamil Nadu Private School Regulation Act of Tamil Nadu Private School Regulation Act
# 19/25  :  acquitted all the accused persons of all the offences charged with under the Dowry Prohibition Act, 1961 against the accused persons of all the offences charged with under the Dowry Prohibition Act, 1961 against the accused persons of all the offences charged with under Section 498-A IPC and Section 3 and 4 of the Dowry Prohibition Act, 1961 against the accused persons of all the offences charged with under Section 498-A IPC and Section 3 and 4 of the Dowry Prohibition Act, 1961 against the accused persons charged with under Section 498-A IPC and Section 498-A IPC and Section 3 and 4 of the Dowry Prohibition Act, 1961 against the accused persons charged with under Section 498-A IPC and Sections 3 and 4 of the Dowry Prohibition Act, 1961 against the accused persons charged with under Section 498-A IPC and Section 498-A IPC and Sections 3 and 4 of the Dowry Prohibition Act, 1961 against the accused persons charged with being charged with being charged with being charged with being charged with being charged with being charged with being charged with being charged with being charged with being
# 20/25  :  The Supreme Court has observed that the respondent No.2 had availed the financial assistance from the respondent No.1 Bank and while availing the financial assistance, the respondent No.2 had mortgaged the property in question in favour of the respondent No.1 Bank. The Supreme Court has observed that the respondent No.1 Bank was in the process of selling the property in question for an amount of Rs.2.50 crores with consent of the respondent No.1 Bank. The Supreme Court has observed that the respondent No.1 Bank had not availed the financial assistance from the financial assistance from the financial assistance from the respondent No.1 Bank. The respondent No.1 Bank. The respondent No.1 Bank was in the process of selling the property in question for an amount of Rs.2.50 crores with consent of the respondent No.1 Bank. The respondent No.1 Bank. The respondent No.1 bank. The respondent No.1 Bank. The respondent No.1 Bank. The respondent No.1 Bank. The respondent No.1 Bank. The respondent No.1 Bank. The respondent No.1 Bank. The respondent No
# 21/25  :  The Supreme Court has found that a petition filed by a husband and wife under the Protection of Women from Domestic Violence Act, 2005 (‘Act’ for short) is not a petition filed by a husband and wife under the Protection of Women from Domestic Violence Act, 2005 (‘Act’ for short). The Supreme Court has found that a petition filed by a husband and wife under the Protection of Women from Domestic Violence Act, 2005 (‘Act’ for short) is not a petition filed by a husband and wife under the Act is a petition filed by a petition filed under the Protection of Women from Domestic Violence Act, 2005 (‘Act’ for enhancement of the Act’ for enhancement of maintenance amount awarded under the Act' for enhancement of maintenance amount awarded under the Act, 'Act' for enhancement of maintenance amount awarded under the Act' for enhancement of maintenance amount awarded under the Act' for enhancement of maintenance amount awarded under the Act' for enhancement of maintenance amount awarded under the Act' for enhancement of maintenance amount awarded under the Act' for enhancement of maintenance amount awarded under the Act' for enhancement of maintenance amount awarded under the Act' for enhancement of maintenance amount awarded under the Act' for enhancement of maintenance amount awarded under
# 22/25  :  the compensation for the lands acquired by the State Government for the purposes of excavation of coal. The compensation awarded by the State Government for the acquisition of coal. The compensation awarded by the Land Acquisition Officer for the purposes of excavation of coal. The compensation was awarded by the High Court for the purposes of excavation of coal. The compensation awarded by the Land Acquisition Officer was awarded at Rs.15,000/­ per acre. The compensation awarded by the High Court was awarded at Rs.15,000/­ per acre. The compensation was awarded at Rs.15,000/­ per acre. The compensation was awarded by the Land Acquisition Officer for the acquisition of coal. The compensation was awarded by the Land Acquisition Officer for the purposes of excavation of coal. The compensation was awarded by the High Court for the purposes of excavation of coal. The compensation was awarded at Rs.10,000/­ per acre. The compensation under Section 6 of the Land Acquisition Officer for the purposes of Rs.10,000/­ per acre. The compensation was awarded by the Land Acquisition Officer for the purpose of Rs.15,000/­ per acre. The Bench Bench Bench Bench Bench Bench Bench Bench Bench Bench Bench Bench Bench Bench Bench Bench Bench Bench Bench Bench Bench Bench Bench Bench Bench
# 23/25  :  The High Court has held that the Court of Justices has held that the criminal proceedings arising out of FIR No. 9/2011 should be quashed. The High Court has held that the Court of Justices has not found that the parties have settled and settled the matter. The High Court has held that the proceedings arising out of FIR No. 9/2011 should be quashed. The Court of Justices has held that the proceedings arising out of FIR No. 9/2011 should be quashed. The High Court has held that the court of Justices have not found that the charges arising out of FIR No. 9/2011 should be quashed. The Court of Justices found that the parties have settled the matter. The Court of Justice K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K K
# 24/25  :  under disposal has been signed by the said SPA of the petitioner/accused. The petitioner/accused has not been named in the FIR and there is no admissible evidence against the petitioner/accused. The petitioner/accused has not been named in the FIR and there is no admissible evidence against the petitioner/accused. The petitioner/accused has not been named in the FIR and there is no admissible evidence against the petitioner/accused. The petitioner/accused has been signed by the said SPA of the petitioner/accused. The petitioner/accused has not been named in the FIR and there is no admissible evidence against the petitioner/accused has not been named in the FIR and there is no admissible evidence against the petitioner/accused. The petitioner/accused. The petitioner/accused. The petitioner/accused. The petitioner/accused. The petitioner/accused. The petitioner/accused. The petitioner/accused. The petitioner/accused. The petitioner/accused has not been named in the FIR and
# 25/25  :  The Supreme Court held that a person is a legal heir to the property of the property of the property of the property of the property of a person. The Supreme Court held that a person is a legal heir to the property of the property of the property of the property of the property of the property of the property of the property of the property of the property of the property of the property of the property of the property of the property of the property of the property of the property of the property of the property of the property of the property of the property of the property of the property of the property of the property of the property of the property of the property of the property of the property of the property of the property of the property of the property of the property of the property of the property of the property of the property of the property of the property of the property of the property of the property of the property of the property of the property of the property of the property of the property of the property of the property of the property of the property of the property of the property of the property of the property of the property of the property of the property of the property in the property of the property of the property of the property of the
# Evaluate:  /content/outputs/MildSum.test.txt
# SARI: 35.21	 D-SARI: 28.74 	 BLEU: 0.89 	 FKGL: 6.87
# Execution time: --- 139.5748143196106 seconds ---

# %%
# Path to the zip file
zip_file_path = '/content/outputs.zip'

if os.path.exists(zip_file_path):
    os.remove(zip_file_path)

#Compress the folder into a zip file
# !zip -r {zip_file_path} {os.path.basename('/content/outputs')}
# Out:
#   adding: outputs/ (stored 0%)
#   adding: outputs/score_MildSum_test.log.txt (deflated 5%)
#   adding: outputs/MildSum.test.txt (deflated 88%)

# %%
from google.colab import files
files.download(f'/content/outputs.zip')
